# %% [markdown]
# <a href="https://colab.research.google.com/github/khoa030602/moeny/blob/main/money.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
from keras.layers import LeakyReLU
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Conv2D, MaxPooling2D, Flatten
from keras.utils import to_categorical
from keras.models import load_model
from keras.utils import load_img, img_to_array
import os
from keras.preprocessing.image import ImageDataGenerator

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Tạo ra class ImageDataGenerator để chỉnh sửa ảnh 
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
#from keras.preprocessing import  ImageDataGenerator
train_datagen=ImageDataGenerator(rescale=1./255, shear_range=0.2, zoom_range=0.2, horizontal_flip=True)

# %%
training_set=train_datagen.flow_from_directory('/content/drive/MyDrive/AI/Data/tien/train',target_size=(150,150), batch_size=32, class_mode='categorical')
# Out:
# Found 90 images belonging to 6 classes.

# %%
# Các nhãn có trong bộ dữ liệu training set
training_set.class_indices
# Out:
# {'100k': 0, '10k': 1, '20k': 2, '500k': 3, '50k': 4, '5k': 5}

# %%
#mô hình CNN
from keras import models
from keras.models import Sequential
from keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Normalization, Dropout
from keras.layers import LeakyReLU

# %%
# Tạo ra mạng CNN để train mô hình
model=Sequential()

# Tích chập 32 lần với mỗi lần là 3 hàng 3 cột
model.add(Conv2D(32,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same',input_shape=(150,150,3))) 
#ham loai bo
model.add(LeakyReLU(alpha = 0.1))
# Lấy phần tử lớn nhất ở trong 2 hàng và 2 cột
model.add(MaxPooling2D(2,2))

# Tích chập 64 lần với mỗi lần là 3 hàng 3 cột
model.add(Conv2D(64,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same')) 
#ham loai bo
model.add(LeakyReLU(alpha = 0.1))
# Lấy phần tử lớn nhất ở trong 2 hàng và 2 cột
model.add(MaxPooling2D(2,2))

# Tích chập 128 lần với mỗi lần là 3 hàng 3 cột
model.add(Conv2D(128,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same')) 
#ham loai bo
model.add(LeakyReLU(alpha = 0.1))
# Lấy phần tử lớn nhất ở trong 2 hàng và 2 cột
model.add(MaxPooling2D(2,2))


# Duỗi thẳng dữ liệu 
model.add(Flatten())

# Tạo lớp thứ nhất với 256 tín hiệu ra
model.add(Dense(256,activation='relu',kernel_initializer='he_uniform'))
# Tạo lớp thứ hai với 3 tín hiệu ra
model.add(Dense(6,activation='softmax'))
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_12 (Conv2D)          (None, 150, 150, 32)      896
#
#  leaky_re_lu_12 (LeakyReLU)  (None, 150, 150, 32)      0
#
#  max_pooling2d_12 (MaxPoolin  (None, 75, 75, 32)       0
#  g2D)
#
#  conv2d_13 (Conv2D)          (None, 75, 75, 64)        18496
#
#  leaky_re_lu_13 (LeakyReLU)  (None, 75, 75, 64)        0
#
#  max_pooling2d_13 (MaxPoolin  (None, 37, 37, 64)       0
#  g2D)
#
#  conv2d_14 (Conv2D)          (None, 37, 37, 128)       73856
#
#  leaky_re_lu_14 (LeakyReLU)  (None, 37, 37, 128)       0
#
#  max_pooling2d_14 (MaxPoolin  (None, 18, 18, 128)      0
#  g2D)
#
#  flatten_4 (Flatten)         (None, 41472)             0
#
#  dense_8 (Dense)             (None, 256)               10617088
#
#  dense_9 (Dense)             (None, 6)                 1542
#
# =================================================================
# Total params: 10,711,878
# Trainable params: 10,711,878
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.utils import to_categorical # one hot encoding cho output
# Biên dịch 
model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
# Gán biến lại để vẽ đồ thị, với 500 lần học (epochs), mỗi lần học thì chỉ học␣128 dữ liệu (batch_size)
history=model.fit(training_set,epochs=50,batch_size=150,verbose=1)
# Out:
# Epoch 1/50
# 3/3 [==============================] - 2s 128ms/step - loss: 3.3408 - accuracy: 0.5444
# Epoch 2/50
# 3/3 [==============================] - 1s 245ms/step - loss: 1.0651 - accuracy: 0.6222
# Epoch 3/50
# 3/3 [==============================] - 1s 311ms/step - loss: 0.9756 - accuracy: 0.7667
# Epoch 4/50
# 3/3 [==============================] - 1s 342ms/step - loss: 0.6167 - accuracy: 0.8000
# Epoch 5/50
# 3/3 [==============================] - 1s 234ms/step - loss: 0.6629 - accuracy: 0.7444
# Epoch 6/50
# 3/3 [==============================] - 1s 230ms/step - loss: 0.6173 - accuracy: 0.7778
# Epoch 7/50
# 3/3 [==============================] - 1s 211ms/step - loss: 0.4437 - accuracy: 0.8667
# Epoch 8/50
# 3/3 [==============================] - 1s 213ms/step - loss: 0.3664 - accuracy: 0.8556
# Epoch 9/50
# 3/3 [==============================] - 1s 227ms/step - loss: 0.2659 - accuracy: 0.9444
# Epoch 10/50
# 3/3 [==============================] - 1s 229ms/step - loss: 0.1892 - accuracy: 0.9667
# Epoch 11/50
# 3/3 [==============================] - 1s 223ms/step - loss: 0.1301 - accuracy: 0.9667
# Epoch 12/50
# 3/3 [==============================] - 1s 218ms/step - loss: 0.0870 - accuracy: 0.9778
# Epoch 13/50
# 3/3 [==============================] - 1s 213ms/step - loss: 0.0805 - accuracy: 0.9778
# Epoch 14/50
# 3/3 [==============================] - 1s 219ms/step - loss: 0.0738 - accuracy: 0.9889
# Epoch 15/50
# 3/3 [==============================] - 1s 215ms/step - loss: 0.0623 - accuracy: 0.9778
# Epoch 16/50
# 3/3 [==============================] - 1s 217ms/step - loss: 0.0889 - accuracy: 0.9667
# Epoch 17/50
# 3/3 [==============================] - 1s 228ms/step - loss: 0.0803 - accuracy: 0.9667
# Epoch 18/50
# 3/3 [==============================] - 1s 303ms/step - loss: 0.0709 - accuracy: 0.9778
# Epoch 19/50
# 3/3 [==============================] - 1s 329ms/step - loss: 0.0993 - accuracy: 0.9556
# Epoch 20/50
# 3/3 [==============================] - 1s 350ms/step - loss: 0.0405 - accuracy: 0.9889
# Epoch 21/50
# 3/3 [==============================] - 1s 356ms/step - loss: 0.0275 - accuracy: 0.9889
# Epoch 22/50
# 3/3 [==============================] - 1s 240ms/step - loss: 0.0307 - accuracy: 1.0000
# Epoch 23/50
# 3/3 [==============================] - 1s 248ms/step - loss: 0.0228 - accuracy: 1.0000
# Epoch 24/50
# 3/3 [==============================] - 1s 237ms/step - loss: 0.0095 - accuracy: 1.0000
# Epoch 25/50
# 3/3 [==============================] - 1s 227ms/step - loss: 0.0203 - accuracy: 1.0000
# Epoch 26/50
# 3/3 [==============================] - 1s 229ms/step - loss: 0.0388 - accuracy: 0.9889
# Epoch 27/50
# 3/3 [==============================] - 1s 221ms/step - loss: 0.0247 - accuracy: 0.9889
# Epoch 28/50
# 3/3 [==============================] - 1s 215ms/step - loss: 0.0060 - accuracy: 1.0000
# Epoch 29/50
# 3/3 [==============================] - 1s 252ms/step - loss: 0.0211 - accuracy: 1.0000
# Epoch 30/50
# 3/3 [==============================] - 1s 217ms/step - loss: 0.0160 - accuracy: 0.9889
# Epoch 31/50
# 3/3 [==============================] - 1s 233ms/step - loss: 0.0093 - accuracy: 1.0000
# Epoch 32/50
# 3/3 [==============================] - 1s 220ms/step - loss: 0.0068 - accuracy: 1.0000
# Epoch 33/50
# 3/3 [==============================] - 1s 220ms/step - loss: 0.0060 - accuracy: 1.0000
# Epoch 34/50
# 3/3 [==============================] - 1s 361ms/step - loss: 0.0037 - accuracy: 1.0000
# Epoch 35/50
# 3/3 [==============================] - 1s 308ms/step - loss: 0.0035 - accuracy: 1.0000
# Epoch 36/50
# 3/3 [==============================] - 1s 288ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 37/50
# 3/3 [==============================] - 1s 225ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 38/50
# 3/3 [==============================] - 1s 238ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 39/50
# 3/3 [==============================] - 1s 226ms/step - loss: 7.7918e-04 - accuracy: 1.0000
# Epoch 40/50
# 3/3 [==============================] - 1s 225ms/step - loss: 4.3907e-04 - accuracy: 1.0000
# Epoch 41/50
# 3/3 [==============================] - 1s 218ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 42/50
# 3/3 [==============================] - 1s 243ms/step - loss: 9.4055e-04 - accuracy: 1.0000
# Epoch 43/50
# 3/3 [==============================] - 1s 214ms/step - loss: 6.0022e-04 - accuracy: 1.0000
# Epoch 44/50
# 3/3 [==============================] - 1s 221ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 45/50
# 3/3 [==============================] - 1s 226ms/step - loss: 2.8731e-04 - accuracy: 1.0000
# Epoch 46/50
# 3/3 [==============================] - 1s 229ms/step - loss: 3.3929e-04 - accuracy: 1.0000
# Epoch 47/50
# 3/3 [==============================] - 1s 239ms/step - loss: 3.1883e-04 - accuracy: 1.0000
# Epoch 48/50
# 3/3 [==============================] - 1s 321ms/step - loss: 1.7386e-04 - accuracy: 1.0000
# Epoch 49/50
# 3/3 [==============================] - 1s 302ms/step - loss: 2.9794e-04 - accuracy: 1.0000
# Epoch 50/50
# 3/3 [==============================] - 1s 343ms/step - loss: 1.9638e-04 - accuracy: 1.0000

# %%
# Đánh giá độ chính xác của mô hình 
Score=model.evaluate(training_set,verbose=0)
print('Train Loss', Score[0])
print('Train Accuracy', Score[1])
# Out:
# Train Loss 0.00022407504729926586
# Train Accuracy 1.0

# %%
from matplotlib import pyplot as plt 
# Vẽ đồ thị giữa số lần học (Epochs) và độ chính xác (Accuracy)
plt.plot(history.history['accuracy'])
plt.plot(history.history['loss'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['Train Accuracy','Train Loss'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Lưu lại
model.save("TienVN_CNN.h5")

# %%
from tensorflow.keras.models import load_model
# Tải mô hình 
model_CNN=load_model('TienVN_CNN.h5')

# %%
from sklearn import preprocessing
from keras.utils import load_img
from keras.utils.image_utils import img_to_array
import os
import numpy as np

# %%
test='/content/drive/MyDrive/AI/Data/tien/test'

for i in os.listdir(test):
  img=load_img(test+'/'+i,target_size=(150,150))
  plt.imshow(img)
  img=img_to_array(img)
  img=img.astype('float32')
  img=img/255
  img=np.expand_dims(img,axis=0)
  
  result = int(np.argmax(model_CNN.predict(img),axis =1))

  class_name=['100.000 VND','10.000 VND','20.000 VND','500.000 VND','50.000 VND','5.000 VND']
  
  print(class_name[result])
  plt.show()
# Out:
# 1/1 [==============================] - 0s 438ms/step
# 50.000 VND
# 1/1 [==============================] - 0s 55ms/step
# 5.000 VND
# 1/1 [==============================] - 0s 28ms/step
# 10.000 VND
# 1/1 [==============================] - 0s 107ms/step
# 20.000 VND
# 1/1 [==============================] - 0s 88ms/step
# 20.000 VND
# 1/1 [==============================] - 0s 44ms/step
# 20.000 VND
# 1/1 [==============================] - 0s 47ms/step
# 50.000 VND
# 1/1 [==============================] - 0s 40ms/step
# 5.000 VND
